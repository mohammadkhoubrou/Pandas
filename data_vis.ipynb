# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
plt.figure(figsize=(14,6))
sns.lineplot(data = data, label = "sinus of numbers")
plt.xlabel("set of numbers")
plt.ylabel("sinus")
# Out:
# /home/mohammad/miniconda3/envs/data/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/mohammad/miniconda3/envs/data/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0, 0.5, 'sinus')

# %%
data = pd.DataFrame({"yes":[1,2,3,4,5,5,6,2,2],"No":[1,2,2,1,2,3,5,8,9]})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 data = pd.DataFrame({"yes":[1,2,3,4,5,6],"No":[1,2,2,1,2,3,5,8,9]})
#
# File ~/miniconda3/envs/data/lib/python3.10/site-packages/pandas/core/frame.py:767, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     761     mgr = self._init_mgr(
#     762         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     763     )
#     765 elif isinstance(data, dict):
#     766     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 767     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     768 elif isinstance(data, ma.MaskedArray):
#     769     from numpy.ma import mrecords
#
# ...

# %%
plt.figure(figsize=(14,6))
sns.heatmap(data=data.iloc[0:45], annot=True)
plt.xlabel("set of numbers")
plt.ylabel("sinus")
# Out:
# Text(145.72222222222223, 0.5, 'sinus')

# %%
sns.barplot(x=data["yes"],y=data.index) #barplot
# Out:
# <Axes: xlabel='yes'>

# %%
import seaborn as sns
data1 = pd.DataFrame({"yes":[1,2,3,4,5,5,6,2,2]})
sns.regplot(x=data1["yes"], y = data.index)
# Out:
# <Axes: xlabel='yes'>
